# %%
import pandas as pd
import json
import time
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError
from geopy.geocoders import Nominatim

buydata_df = pd.read_json('buy_data.json')

# %%
buydata_df
# Out:
#                                                 title       price     area  \
# 0   Xưởng sản xuất tại hóc môn mặt tiền đường hạ t...        29Tỷ   4150.0
# 1   Cần chuyển nhượng lại khu nghỉ dưỡng sinh thái...  Thỏa thuận  30000.0
# 2   Chính chủ cần bán gấp lô đất ngay p tam phước ...       1,2Tỷ    120.0
# 3   Mở bán 15 nền đất trong khu tái định cư mới q1...      1,55Tỷ     81.0
# 4   Bán tòa nhà văn phòng mặt phố yên xá, 7 tầng, ...      23,5Tỷ    100.0
# 5   Chính cần bán nhà 2 măt tiền kinh doanh được t...      6,88Tỷ     72.5
# 6   Cơ hội sở hữu lô đất đắc địa tại huyện lương s...  Thỏa thuận    800.0
# 7   Bán nhà 72.5m2 shr cách hxh 5m sát đường hà hu...       3,9Tỷ     72.5
# 8   Bán quỹ ngoại giao căn 77m2 toà l1 giá chỉ 3,5...       3,5Tỷ     77.0
# 9   5 căn hộ ngoại giao giá tốt nhất thị trường dự...         4Tỷ     89.0
# 10  Cần bán 1280m2 lô đất vuông vắn view cánh đồng...       5,5Tỷ   1280.0
# 11    Cần bán lô đất 418m2 thuộc xã cao sơn lương sơn       1,8Tỷ    418.0
#
#        type                                            address  \
# 0   Mua Bán        Xã Tân Thới Nhì, Huyện Hóc Môn, Hồ Chí Minh
# 1   Mua Bán               Xã Cư Yên, Huyện Lương Sơn, Hòa Bình
# 2   Mua Bán         Xã Tam Phước, Thành phố Biên Hòa, Đồng Nai
# 3   Mua Bán         Phường Tân Thới Nhất, Quận 12, Hồ Chí Minh
# 4   Mua Bán              Xã Tân Triều, Huyện Thanh Trì, Hà Nội
# 5   Mua Bán               Xã Tam Hưng, Huyện Thanh Oai, Hà Nội
# 6   Mua Bán      Thị Trấn Lương Sơn, Huyện Lương Sơn, Hòa Bình
# 7   Mua Bán            Phường Thạnh Xuân, Quận 12, Hồ Chí Minh
# 8   Mua Bán  Le Grand Jardin, Phường Sài Đồng, Quận Long Bi...
# 9   Mua Bán  Khai Sơn City, Phường Ngọc Thụy, Quận Long Biê...
# 10  Mua Bán      Thị Trấn Lương Sơn, Huyện Lương Sơn, Hòa Bình
# 11  Mua Bán              Xã Hợp Hòa, Huyện Lương Sơn, Hòa Bình
#
#                                           description                    law  \
# 0   Xác thực chính chủ Đất nông nghiệp, 1 phần thổ...               Có Sổ đỏ
# 1   Cần chuyển nhượng lại khu nghỉ dưỡng sinh thái...  Văn bản Chuyển nhượng
# 2   Cần tiền bán gấp lô đất ngay đường E Khu Phố L...               Có Sổ đỏ
# 3   Mở bán 15 nền Khu Dân Cư Quận 12-Gần Cầu Th...               Có Sổ đỏ
# 4   Bán Tòa Nhà Văn Phòng Mặt Phố Yên Xá, Vị Trí Đ...               Có Sổ đỏ
# 5   Xác thực chính chủ Bán nhà 2 mặt tiền- đường T...               Có Sổ đỏ
# 6   Với khuôn viên nhà vườn nghỉ dưỡng cuối tuần, ...       Hợp đồng Mua bán
# 7   Xác thực chính chủ - Căn nhà thích hợp cho ngư...               Có Sổ đỏ
# 8   * Chỉ từ 990tr sở hữu ngay căn 2 phòng ngủ chu...               Có Sổ đỏ
# 9   Top 5 căn đang được kh săn đón nhiều nhất. Top...               Có Sổ đỏ
# 10  Thông tin chi tiết: DT: 1280m2 trong đó có 400...               Có Sổ đỏ
# 11  📣Bán 418m2 lô đất nhỏ xinh view cánh đồng - Lô...               Có Sổ đỏ
#
#                      type_estate     province   district  bedroom  toilet  \
# 0   Nhà xưởng, mặt bằng, kho bãi  Hồ Chí Minh    Hóc Môn      NaN     NaN
# 1    Nhà hàng, khách sạn, resort     Hòa Bình  Lương Sơn      NaN     NaN
# 2                 Nhà đất thổ cư     Đồng Nai   Biên Hòa      NaN     NaN
# 3                 Nhà đất thổ cư  Hồ Chí Minh         12      NaN     NaN
# 4                    Nhà mặt phố       Hà Nội  Thanh Trì      7.0     NaN
# 5                 Nhà đất thổ cư       Hà Nội  Thanh Oai      NaN     NaN
# 6                 Đất trang trại     Hòa Bình  Lương Sơn      NaN     NaN
# 7                  Nhà trong ngõ  Hồ Chí Minh         12      3.0     3.0
# 8                Căn hộ chung cư       Hà Nội  Long Biên      2.0     2.0
# 9                Căn hộ chung cư       Hà Nội  Long Biên      2.0     2.0
# 10                Nhà đất thổ cư     Hòa Bình  Lương Sơn      NaN     NaN
# 11                Nhà đất thổ cư     Hòa Bình  Lương Sơn      NaN     NaN
#
#         floor direction entrance_width   width  \
# 0    1 (Tầng)      None         10 (m)  62 (m)
# 1        None      None           None    None
# 2        None  Đông nam         16 (m)   5 (m)
# 3        None  Đông nam         12 (m)   6 (m)
# 4    7 (Tầng)      None         20 (m)  20 (m)
# 5        None      None           None    None
# 6        None      None           None    None
# 7    2 (Tầng)  Đông nam          3 (m)   4 (m)
# 8        None  Đông nam           None    None
# 9   22 (Tầng)  Đông nam           None    None
# 10       None      None          7 (m)    None
# 11       None  Đông nam          7 (m)    None
#
#                                           image_links
# 0   https://nhadat24h.net//Upload/User/DangTin/202...
# 1   https://nhadat24h.net//Upload/User/DangTin/202...
# 2   https://nhadat24h.net//Upload/User/DangTin/202...
# 3   https://nhadat24h.net//Upload/User/DangTin/202...
# 4   https://nhadat24h.net//Upload/User/DangTin/202...
# 5   https://nhadat24h.net//Upload/User/DangTin/202...
# 6   https://nhadat24h.net//Upload/User/DangTin/202...
# 7   https://nhadat24h.net//Upload/User/DangTin/202...
# 8   https://nhadat24h.net//Upload/User/DangTin/202...
# 9   https://nhadat24h.net//Upload/User/DangTin/202...
# 10  https://nhadat24h.net//Upload/User/DangTin/202...
# 11  https://nhadat24h.net//Upload/User/DangTin/202...

# %%
title = []                  # 1
price = []                  # 2
area = []                   # 3
bedroom = []        # 4
description = []            # 5
width = []                  # 6
direction = []              # 7
toilet = []         # 8
address = []               # 9
geo_code = []               # 10
law = []
floor = []
district = []
province = []
type = []
type_estate = []
image_links = []

# %%
# Add new column with default None values for geocodes
buydata_df["geo_code"] = [None for _ in range(len(buydata_df))]

def get_geocode(address):
    geolocator = Nominatim(user_agent="my_geocoder")
    
    # Retry parameters
    max_retries = 3
    retry_delay = 2  # seconds
    
    for attempt in range(max_retries):
        try:    
            location = geolocator.geocode(address + ", Vietnam", timeout=15)  # Add country information
            if location:
                return [location.latitude, location.longitude]
            else:
                # print(f"Error: Address not found for {address}!")
                return None
        except (GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError) as e:            
            print(f"Geocoder unavailable (attempt {attempt + 1}/{max_retries}). Retrying after {retry_delay} seconds.")
            time.sleep(retry_delay)
            retry_delay *= 2  # Exponential backoff
    return None

if 'address' in buydata_df.columns:
    for i, address in enumerate(buydata_df["address"]):
        buydata_df.at[i, "geo_code"] = get_geocode(address)
else:
    print("Error: 'address' column not found in the DataFrame.")

def data_normalization(df):
    for i, price in enumerate(df['price']):
        # Loại bỏ khoảng trắng thừa
        price = price.strip()
        
        # Thay thế dấu phẩy bằng dấu chấm
        price = price.replace(',', '.')
        
        # Kiểm tra và xử lý nếu tồn tại từ 'Triệu'
        if 'Triệu' in price:
            # Loại bỏ từ 'Triệu' và khoảng trắng
            price = price.replace('Triệu', '').strip()
            # Chuyển đổi giá trị thành tỷ
            price = float(price) / 1000  # Chia cho 1000 để đổi từ triệu thành tỷ
        # Kiểm tra và xử lý nếu tồn tại từ 'Tỷ'
        elif 'Tỷ' in price:
            price = price.replace('Tỷ', '').strip()
            # Chuyển đổi giá trị thành float
            price = float(price)
        else:
            # Loại bỏ các dấu chấm ngăn cách phần nghìn, triệu (nếu có)
            if '.' in price and price.count('.') > 1:
                price = price.replace('.', '', price.count('.') - 1)           
            

        # Gán lại giá trị vào dataframe
        df.at[i, 'price'] = price
    for i, width in enumerate(df['width']):
        if isinstance(width, str):
            df.at[i, "width"] = width.replace("(m)", '').strip()
        
    for i, floor in enumerate(df['floor']):
        if isinstance(floor, str):
            df.at[i, "floor"] = floor.replace("(Tầng)", '').strip()

data_normalization(buydata_df)

def write_data(df, field, data_list):
    if not isinstance(data_list, list):
        data_list = []  # Initialize as empty list if not already
    
    if field in df.columns:
        for value in df[field]:
            data_list.append(value)
    else:
        print(f"Error: '{field}' column not found in the DataFrame.")

write_data(buydata_df, "title", title)
write_data(buydata_df, "price", price)
write_data(buydata_df, "area", area)
write_data(buydata_df, "type", type)
write_data(buydata_df, "type_estate", type_estate)
write_data(buydata_df, "image_links", image_links)
write_data(buydata_df, "bedroom", bedroom)
write_data(buydata_df, "description", description)
write_data(buydata_df, "width", width)
write_data(buydata_df, "direction", direction)
write_data(buydata_df, "toilet", toilet)
write_data(buydata_df, "address", address)
write_data(buydata_df, "law", law)
write_data(buydata_df, "floor", floor)
write_data(buydata_df, "geo_code", geo_code)

# Display the updated DataFrame
print("\nUpdated DataFrame:")
# Out:
# Updated DataFrame:

# %%
buydata_df
# Out:
#                                                 title       price     area  \
# 0   Xưởng sản xuất tại hóc môn mặt tiền đường hạ t...        29.0   4150.0
# 1   Cần chuyển nhượng lại khu nghỉ dưỡng sinh thái...  Thỏa thuận  30000.0
# 2   Chính chủ cần bán gấp lô đất ngay p tam phước ...         1.2    120.0
# 3   Mở bán 15 nền đất trong khu tái định cư mới q1...        1.55     81.0
# 4   Bán tòa nhà văn phòng mặt phố yên xá, 7 tầng, ...        23.5    100.0
# 5   Chính cần bán nhà 2 măt tiền kinh doanh được t...        6.88     72.5
# 6   Cơ hội sở hữu lô đất đắc địa tại huyện lương s...  Thỏa thuận    800.0
# 7   Bán nhà 72.5m2 shr cách hxh 5m sát đường hà hu...         3.9     72.5
# 8   Bán quỹ ngoại giao căn 77m2 toà l1 giá chỉ 3,5...         3.5     77.0
# 9   5 căn hộ ngoại giao giá tốt nhất thị trường dự...         4.0     89.0
# 10  Cần bán 1280m2 lô đất vuông vắn view cánh đồng...         5.5   1280.0
# 11    Cần bán lô đất 418m2 thuộc xã cao sơn lương sơn         1.8    418.0
#
#        type                                            address  \
# 0   Mua Bán        Xã Tân Thới Nhì, Huyện Hóc Môn, Hồ Chí Minh
# 1   Mua Bán               Xã Cư Yên, Huyện Lương Sơn, Hòa Bình
# 2   Mua Bán         Xã Tam Phước, Thành phố Biên Hòa, Đồng Nai
# 3   Mua Bán         Phường Tân Thới Nhất, Quận 12, Hồ Chí Minh
# 4   Mua Bán              Xã Tân Triều, Huyện Thanh Trì, Hà Nội
# 5   Mua Bán               Xã Tam Hưng, Huyện Thanh Oai, Hà Nội
# 6   Mua Bán      Thị Trấn Lương Sơn, Huyện Lương Sơn, Hòa Bình
# 7   Mua Bán            Phường Thạnh Xuân, Quận 12, Hồ Chí Minh
# 8   Mua Bán  Le Grand Jardin, Phường Sài Đồng, Quận Long Bi...
# 9   Mua Bán  Khai Sơn City, Phường Ngọc Thụy, Quận Long Biê...
# 10  Mua Bán      Thị Trấn Lương Sơn, Huyện Lương Sơn, Hòa Bình
# 11  Mua Bán              Xã Hợp Hòa, Huyện Lương Sơn, Hòa Bình
#
#                                           description                    law  \
# 0   Xác thực chính chủ Đất nông nghiệp, 1 phần thổ...               Có Sổ đỏ
# 1   Cần chuyển nhượng lại khu nghỉ dưỡng sinh thái...  Văn bản Chuyển nhượng
# 2   Cần tiền bán gấp lô đất ngay đường E Khu Phố L...               Có Sổ đỏ
# 3   Mở bán 15 nền Khu Dân Cư Quận 12-Gần Cầu Th...               Có Sổ đỏ
# 4   Bán Tòa Nhà Văn Phòng Mặt Phố Yên Xá, Vị Trí Đ...               Có Sổ đỏ
# 5   Xác thực chính chủ Bán nhà 2 mặt tiền- đường T...               Có Sổ đỏ
# 6   Với khuôn viên nhà vườn nghỉ dưỡng cuối tuần, ...       Hợp đồng Mua bán
# 7   Xác thực chính chủ - Căn nhà thích hợp cho ngư...               Có Sổ đỏ
# 8   * Chỉ từ 990tr sở hữu ngay căn 2 phòng ngủ chu...               Có Sổ đỏ
# 9   Top 5 căn đang được kh săn đón nhiều nhất. Top...               Có Sổ đỏ
# 10  Thông tin chi tiết: DT: 1280m2 trong đó có 400...               Có Sổ đỏ
# 11  📣Bán 418m2 lô đất nhỏ xinh view cánh đồng - Lô...               Có Sổ đỏ
#
#                      type_estate     province   district  bedroom  toilet  \
# 0   Nhà xưởng, mặt bằng, kho bãi  Hồ Chí Minh    Hóc Môn      NaN     NaN
# 1    Nhà hàng, khách sạn, resort     Hòa Bình  Lương Sơn      NaN     NaN
# 2                 Nhà đất thổ cư     Đồng Nai   Biên Hòa      NaN     NaN
# 3                 Nhà đất thổ cư  Hồ Chí Minh         12      NaN     NaN
# 4                    Nhà mặt phố       Hà Nội  Thanh Trì      7.0     NaN
# 5                 Nhà đất thổ cư       Hà Nội  Thanh Oai      NaN     NaN
# 6                 Đất trang trại     Hòa Bình  Lương Sơn      NaN     NaN
# 7                  Nhà trong ngõ  Hồ Chí Minh         12      3.0     3.0
# 8                Căn hộ chung cư       Hà Nội  Long Biên      2.0     2.0
# 9                Căn hộ chung cư       Hà Nội  Long Biên      2.0     2.0
# 10                Nhà đất thổ cư     Hòa Bình  Lương Sơn      NaN     NaN
# 11                Nhà đất thổ cư     Hòa Bình  Lương Sơn      NaN     NaN
#
#    floor direction entrance_width width  \
# 0      1      None         10 (m)    62
# 1   None      None           None  None
# 2   None  Đông nam         16 (m)     5
# 3   None  Đông nam         12 (m)     6
# 4      7      None         20 (m)    20
# 5   None      None           None  None
# 6   None      None           None  None
# 7      2  Đông nam          3 (m)     4
# 8   None  Đông nam           None  None
# 9     22  Đông nam           None  None
# 10  None      None          7 (m)  None
# 11  None  Đông nam          7 (m)  None
#
#                                           image_links  \
# 0   https://nhadat24h.net//Upload/User/DangTin/202...
# 1   https://nhadat24h.net//Upload/User/DangTin/202...
# 2   https://nhadat24h.net//Upload/User/DangTin/202...
# 3   https://nhadat24h.net//Upload/User/DangTin/202...
# 4   https://nhadat24h.net//Upload/User/DangTin/202...
# 5   https://nhadat24h.net//Upload/User/DangTin/202...
# 6   https://nhadat24h.net//Upload/User/DangTin/202...
# 7   https://nhadat24h.net//Upload/User/DangTin/202...
# 8   https://nhadat24h.net//Upload/User/DangTin/202...
# 9   https://nhadat24h.net//Upload/User/DangTin/202...
# 10  https://nhadat24h.net//Upload/User/DangTin/202...
# 11  https://nhadat24h.net//Upload/User/DangTin/202...
#
#                                     geo_code
# 0                   [10.8933224, 106.578884]
# 1                                       None
# 2                   [10.854786, 106.9281012]
# 3                  [10.8306721, 106.6151355]
# 4                  [20.9770834, 105.8042144]
# 5                  [20.8837388, 105.7901402]
# 6                  [20.9046813, 105.5786736]
# 7                  [10.8719549, 106.6726095]
# 8   [21.036419449999997, 105.90697304076582]
# 9          [21.06061875, 105.88019297346938]
# 10                 [20.9046813, 105.5786736]
# 11                                      None

# %%
buydata_df.to_csv('buy_data.csv', encoding='utf-8', index=False)

# %%
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

try:
    with connection.cursor() as cursor:
        # Xóa dữ liệu từ cả hai bảng pools_bds và pools_image
        cursor.execute("""
            DELETE pb, pi
            FROM pools_bds pb
            JOIN pools_image pi ON pb.BDS_id = pi.BDS_id
            WHERE pb.kind = 'Mua Bán' AND pi.content LIKE '%nhadat24h.net%'
        """)
        connection.commit()

finally:
    connection.close()

# %%
import csv
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL với mã hóa utf8mb4
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

def is_decimal(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

try:
    with connection.cursor() as cursor:
        
        # Đọc dữ liệu từ file CSV và nhập vào MySQL
        with open('buy_data.csv', 'r', encoding='utf-8') as file:
            csv_data = csv.DictReader(file)
            for row in csv_data:
                try:
                    district = row['district']
                    province_city = row['province']
                    
                    # Kiểm tra tồn tại address
                    cursor.execute("SELECT address_id FROM pools_address WHERE district = %s AND province_city = %s", (district, province_city))
                    existing_address = cursor.fetchone()
                    if existing_address:
                        address_id = existing_address['address_id']
                    else:
                        # Nếu không tìm thấy địa chỉ, bỏ qua dòng này
                        print(f"Không tìm thấy địa chỉ cho dòng: {row}")
                        continue
                    
                    # Kiểm tra pools_typeofbds 
                    bds_type = row['type_estate']
                    cursor.execute("SELECT Type_Id FROM pools_typeofbds WHERE TypeName = %s", (bds_type,))
                    existing_type = cursor.fetchone()
                    if existing_type:
                        type_id = existing_type['Type_Id']
                    else:
                        # Nếu không tìm thấy loại bất động sản, bỏ qua dòng này
                        print(f"Không tìm thấy loại bất động sản cho dòng: {row}")
                        continue
                    
                    # Thêm dữ liệu vào bảng pools_bds
                    title = row['title']
                    price = row['price']
                    area = row['area']
                    kind = row['type']
                    law = row['law']
                    bedroom = row['bedroom']
                    floor = row['floor']
                    description = row['description']
                    width = row['width']
                    direction = row['direction']
                    toilet = row['toilet']
                    location = row['address']
                    geocode = row['geo_code']
                    
                    # Handle 'price' column
                    if price.strip().lower() == 'thỏa thuận':
                        price = 0  # or set to a default value, like 0
                    elif not is_decimal(price):
                        price = 0  # or set to a default value

                    # Handle 'width' column
                    if not is_decimal(width):
                        width = 0  # or set to a default value

                    # Handle 'bedroom' column
                    if not bedroom.strip() or bedroom.lower() == 'null':
                        bedroom = 0  # or set to a default value
                       
                    # Handle 'floor' column 
                    if not floor.strip() or floor.lower() == 'null':
                        floor = 0  # or set to a default value

                    # Handle 'toilet' column (if needed)
                    if not is_decimal(toilet):
                        toilet = 0  # or set to a default value

                    # Kiểm tra geocode nếu là None hoặc rỗng, bỏ qua dòng này
                    if not geocode:
                        # print(f"Không có giá trị geocode cho dòng: {row}")
                        continue

                    # Chuyển geo_code thành string nếu nó là list
                    if isinstance(geocode, list):
                        geocode = str(geocode)

                    # Thêm dữ liệu vào bảng pools_bds
                    cursor.execute("""
                        INSERT INTO pools_bds (title, price, area, kind, law, bedroom, floor, address_id, Type_id, description, width, direction, toilet, location, geocode)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                    """, (title, price, area, kind, law, bedroom, floor, address_id, type_id, description, width, direction, toilet, location, geocode))
                    connection.commit()
                    
                    # Lấy BDS_id của BDS vừa thêm
                    cursor.execute("SELECT LAST_INSERT_ID()")
                    bds_id = cursor.fetchone()['LAST_INSERT_ID()']
                    
                    # Thêm dữ liệu vào bảng pools_image (nếu có)
                    if 'image_links' in row and row['image_links']:  # Kiểm tra xem cột 'image_link' có tồn tại và có giá trị không
                        image_link = row['image_links']
                        cursor.execute("INSERT INTO pools_image (BDS_id, content) VALUES (%s, %s)", (bds_id, image_link))
                        connection.commit()
                        
                except Exception as e:
                    print(f"Lỗi khi xử lý dòng: {row}")
                    print(e)
finally:
    connection.close()
