# %%
import pandas as pd
import json
import time
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError
from geopy.geocoders import Nominatim

buydata_df = pd.read_json('buy_data.json')

# %%
buydata_df
# Out:
#                                                  title       price     area  \
# 0    Cần chuyển nhượng lại khu nghỉ dưỡng sinh thái...  Thỏa thuận  30000.0
# 1              Bán nhà mặt đường hồng hà hoàn kiếm 62m    190Triệu     62.0
# 2    Chính cần bán nhà 2 măt tiền kinh doanh được t...      6,88Tỷ     72.5
# 3    Cơ hội sở hữu lô đất đắc địa tại huyện lương s...  Thỏa thuận    800.0
# 4    BÁN NHÀ PHỐ ĐA SỸ HÀ ĐÔNG - MẶT NGÕ KINH DOANH...  Thỏa thuận     35.0
# ..                                                 ...         ...      ...
# 971  Hot hiếm bán 99m đình trung xuân nộn đông anh ...      2,45Tỷ     99.0
# 972  🔥 🔥chỉ hơn 1 tỷ có ngay 1 lô đất gần 44m2 tại ...       1,3Tỷ     44.0
# 973  Cần bán gấp 3,7ha đất thổ cư giá đầu tư xã yên...        25Tỷ  37000.0
# 974  Cần chuyển nhượng lô đất 808m gần khu công ngh...         5Tỷ    808.0
# 975    Cần bán nhanh 1952m2 đất nhuận trạch giá đầu tư       6,9Tỷ   1952.0
#
#         type                                            address  \
# 0    Mua Bán               Xã Cư Yên, Huyện Lương Sơn, Hòa Bình
# 1    Mua Bán   Hồng hà, Phường Phúc Tân, Quận Hoàn Kiếm, Hà Nội
# 2    Mua Bán               Xã Tam Hưng, Huyện Thanh Oai, Hà Nội
# 3    Mua Bán      Thị Trấn Lương Sơn, Huyện Lương Sơn, Hòa Bình
# 4    Mua Bán  Đường Đa sĩ, Phường Kiến Hưng, Quận Hà Đông, H...
# ..       ...                                                ...
# 971  Mua Bán                Xã Xuân Nộn, Huyện Đông Anh, Hà Nội
# 972  Mua Bán         Thị Trấn Quang Minh, Huyện Mê Linh, Hà Nội
# 973  Mua Bán  Kđt Xanh Villas, Xã Bình Yên, Huyện Thạch Thất...
# 974  Mua Bán             Xã Yên Trung, Huyện Thạch Thất, Hà Nội
# 975  Mua Bán          Xã Nhuận Trạch, Huyện Lương Sơn, Hòa Bình
#
#                                            description                    law  \
# 0    <p>Cần chuyển nhượng lại khu nghỉ dưỡng sinh t...  Văn bản Chuyển nhượng
# 1    Chính chủ cần bán nhà mặt đường Hồng Hà hoàn K...       Hợp đồng Mua bán
# 2    <p>Bán nhà 2 mặt tiền- đường Tam Hưng, cạnh UB...               Có Sổ đỏ
# 3    <p>Với khuôn viên nhà vườn nghỉ dưỡng cuối tuầ...       Hợp đồng Mua bán
# 4    <p class="p1"></p><p class="p1"></p><p class="...               Có Sổ đỏ
# ..                                                 ...                    ...
# 971  <p>✅Mô tả:</p><p>👉Đất 98.6m, Mặt tiền = Hậu: 4...               Có Sổ đỏ
# 972  <p>✅ ĐẤT NỞ HẬU - FULL THỔ CƯ - ĐẤT Ở ĐÔ THỊ -...               Có Sổ đỏ
# 973  Khu đất đất là một thung lũng độc lập, có ao, ...               Có Sổ đỏ
# 974  Lô đất bám mặt đường liên xã hơn 20m, sau lưng...               Có Sổ đỏ
# 975  Thông tin chi tiết:\n<br/>Diện tích 1952m2 tro...               Có Sổ đỏ
#
#                      type_estate  province    district  bedroom  toilet  \
# 0    Nhà hàng, khách sạn, resort  Hòa Bình   Lương Sơn      NaN     NaN
# 1                    Nhà mặt phố    Hà Nội   Hoàn Kiếm      2.0     3.0
# 2                 Nhà đất thổ cư    Hà Nội   Thanh Oai      NaN     NaN
# 3                 Đất trang trại  Hòa Bình   Lương Sơn      NaN     NaN
# 4                 Nhà đất thổ cư    Hà Nội     Hà Đông      3.0     4.0
# ..                           ...       ...         ...      ...     ...
# 971               Nhà đất thổ cư    Hà Nội    Đông Anh      1.0     1.0
# 972               Nhà đất thổ cư    Hà Nội     Mê Linh      1.0     1.0
# 973               Nhà đất thổ cư    Hà Nội  Thạch Thất      NaN     NaN
# 974               Nhà đất thổ cư    Hà Nội  Thạch Thất      NaN     NaN
# 975               Nhà đất thổ cư  Hòa Bình   Lương Sơn      NaN     NaN
#
#         floor direction entrance_width  width  \
# 0        None      None           None   None
# 1    4 (Tầng)      None         11 (m)  6 (m)
# 2        None      None           None   None
# 3        None      None           None   None
# 4    5 (Tầng)      None          4 (m)  4 (m)
# ..        ...       ...            ...    ...
# 971      None      None          4 (m)  4 (m)
# 972      None      None          3 (m)  4 (m)
# 973      None      None          7 (m)   None
# 974      None  Đông nam          7 (m)   None
# 975      None      None          4 (m)   None
#
#                                            image_links phonenumber
# 0    https://nhadat24h.net//Upload/User/DangTin/202...  0926939389
# 1    https://nhadat24h.net//Upload/User/DangTin/202...  0936391186
# 2    https://nhadat24h.net//Upload/User/DangTin/202...  0989124334
# 3    https://nhadat24h.net//Upload/User/DangTin/202...  0926939389
# 4    https://nhadat24h.net/https://nhadat24h01.blob...  0397033017
# ..                                                 ...         ...
# 971  https://nhadat24h.net//Upload/User/DangTin/202...  0567111121
# 972  https://nhadat24h.net//Upload/User/DangTin/202...  0567111121
# 973  https://nhadat24h.net//Upload/User/DangTin/202...  0968028768
# 974  https://nhadat24h.net//Upload/User/DangTin/202...  0968028768
# 975  https://nhadat24h.net//Upload/User/DangTin/202...  0968028768
#
# [976 rows x 18 columns]

# %%
title = []                  # 1
price = []                  # 2
area = []                   # 3
bedroom = []        # 4
description = []            # 5
width = []                  # 6
direction = []              # 7
toilet = []         # 8
address = []               # 9
geo_code = []               # 10
law = []
floor = []
district = []
province = []
type = []
type_estate = []
image_links = []
phonenumber = []

# %%
import re
# Add new column with default None values for geocodes
buydata_df["geo_code"] = [None for _ in range(len(buydata_df))]

def get_geocode(address):
    geolocator = Nominatim(user_agent="my_geocoder")
    
    # Retry parameters
    max_retries = 3
    retry_delay = 1  # seconds
    
    for attempt in range(max_retries):
        try:    
            location = geolocator.geocode(address + ", Vietnam", timeout=15)  # Add country information
            if location:
                return [location.latitude, location.longitude]
            else:
                # print(f"Error: Address not found for {address}!")
                return None
        except (GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError) as e:            
            print(f"Geocoder unavailable (attempt {attempt + 1}/{max_retries}). Retrying after {retry_delay} seconds.")
            time.sleep(retry_delay)
            retry_delay *= 2  # Exponential backoff
    return None

if 'address' in buydata_df.columns:
    for i, address in enumerate(buydata_df["address"]):
        buydata_df.at[i, "geo_code"] = get_geocode(address)
else:
    print("Error: 'address' column not found in the DataFrame.")

def data_normalization(df):
    for i, price in enumerate(df['price']):
        price = str(price)
        
        price = price.replace(',', '.').strip()        
        # Kiểm tra và xử lý nếu tồn tại từ 'Triệu'
        if 'Triệu' in price:
            # Loại bỏ từ 'Triệu' và khoảng trắng
            price = price.replace('Triệu', '').strip()
            # Chuyển đổi giá trị thành tỷ
            price = float(price) / 1000  # Chia cho 1000 để đổi từ triệu thành tỷ
        # Kiểm tra và xử lý nếu tồn tại từ 'Tỷ'
        elif 'Tỷ' in price:
            price = price.replace('Tỷ', '').strip()
            # Chuyển đổi giá trị thành float
            price = float(price)
        else:
            # Loại bỏ các dấu chấm ngăn cách phần nghìn, triệu (nếu có)
            if '.' in price and price.count('.') > 1:
                price = price.replace('.', '', price.count('.') - 1)           
            

        # Gán lại giá trị vào dataframe
        df.at[i, 'price'] = price
    for i, width in enumerate(df['width']):
        if isinstance(width, str):
            df.at[i, "width"] = width.replace("(m)", '').strip()
        
    for i, floor in enumerate(df['floor']):
        if isinstance(floor, str):
            df.at[i, "floor"] = floor.replace("(Tầng)", '').strip()
    
    for i, phonenumber in enumerate(df['phonenumber']):        
        if isinstance(phonenumber, str):
            phonenumber = phonenumber.replace(' ', '').replace('.', '').strip()
            # Kiểm tra nếu số đầu tiên khác 0 thì thêm số 0 vào đầu
            if phonenumber[0] != '0':
                phonenumber = '0' + phonenumber
            df.at[i, 'phonenumber'] = phonenumber.strip()
            
    for i, title in enumerate(df['title']):
        if isinstance(title, str):
            title = re.sub(r'[^\w\s,.()\–]', '', title)
            title = title.lower()
            title = title.capitalize()
            df.at[i, 'title'] = title.strip()

data_normalization(buydata_df)

def write_data(df, field, data_list):
    if not isinstance(data_list, list):
        data_list = []  # Initialize as empty list if not already
    
    if field in df.columns:
        for value in df[field]:
            data_list.append(value)
    else:
        print(f"Error: '{field}' column not found in the DataFrame.")

write_data(buydata_df, "title", title)
write_data(buydata_df, "price", price)
write_data(buydata_df, "area", area)
write_data(buydata_df, "type", type)
write_data(buydata_df, "type_estate", type_estate)
write_data(buydata_df, "image_links", image_links)
write_data(buydata_df, "bedroom", bedroom)
write_data(buydata_df, "description", description)
write_data(buydata_df, "width", width)
write_data(buydata_df, "direction", direction)
write_data(buydata_df, "toilet", toilet)
write_data(buydata_df, "address", address)
write_data(buydata_df, "law", law)
write_data(buydata_df, "floor", floor)
write_data(buydata_df, "geo_code", geo_code)
write_data(buydata_df, "phonenumber", phonenumber)

# Display the updated DataFrame
print("\nUpdated DataFrame:")
# Out:
# Updated DataFrame:

# %%
buydata_df
# Out:
#                                                  title       price     area  \
# 0    Cần chuyển nhượng lại khu nghỉ dưỡng sinh thái...  Thỏa thuận  30000.0
# 1              Bán nhà mặt đường hồng hà hoàn kiếm 62m        0.19     62.0
# 2    Chính cần bán nhà 2 măt tiền kinh doanh được t...        6.88     72.5
# 3    Cơ hội sở hữu lô đất đắc địa tại huyện lương s...  Thỏa thuận    800.0
# 4    Bán nhà phố đa sỹ hà đông  mặt ngõ kinh doanh ...  Thỏa thuận     35.0
# ..                                                 ...         ...      ...
# 971  Hot hiếm bán 99m đình trung xuân nộn đông anh ...        2.45     99.0
# 972  chỉ hơn 1 tỷ có ngay 1 lô đất gần 44m2 tại thị...         1.3     44.0
# 973  Cần bán gấp 3,7ha đất thổ cư giá đầu tư xã yên...        25.0  37000.0
# 974  Cần chuyển nhượng lô đất 808m gần khu công ngh...         5.0    808.0
# 975    Cần bán nhanh 1952m2 đất nhuận trạch giá đầu tư         6.9   1952.0
#
#         type                                            address  \
# 0    Mua Bán               Xã Cư Yên, Huyện Lương Sơn, Hòa Bình
# 1    Mua Bán   Hồng hà, Phường Phúc Tân, Quận Hoàn Kiếm, Hà Nội
# 2    Mua Bán               Xã Tam Hưng, Huyện Thanh Oai, Hà Nội
# 3    Mua Bán      Thị Trấn Lương Sơn, Huyện Lương Sơn, Hòa Bình
# 4    Mua Bán  Đường Đa sĩ, Phường Kiến Hưng, Quận Hà Đông, H...
# ..       ...                                                ...
# 971  Mua Bán                Xã Xuân Nộn, Huyện Đông Anh, Hà Nội
# 972  Mua Bán         Thị Trấn Quang Minh, Huyện Mê Linh, Hà Nội
# 973  Mua Bán  Kđt Xanh Villas, Xã Bình Yên, Huyện Thạch Thất...
# 974  Mua Bán             Xã Yên Trung, Huyện Thạch Thất, Hà Nội
# 975  Mua Bán          Xã Nhuận Trạch, Huyện Lương Sơn, Hòa Bình
#
#                                            description                    law  \
# 0    <p>Cần chuyển nhượng lại khu nghỉ dưỡng sinh t...  Văn bản Chuyển nhượng
# 1    Chính chủ cần bán nhà mặt đường Hồng Hà hoàn K...       Hợp đồng Mua bán
# 2    <p>Bán nhà 2 mặt tiền- đường Tam Hưng, cạnh UB...               Có Sổ đỏ
# 3    <p>Với khuôn viên nhà vườn nghỉ dưỡng cuối tuầ...       Hợp đồng Mua bán
# 4    <p class="p1"></p><p class="p1"></p><p class="...               Có Sổ đỏ
# ..                                                 ...                    ...
# 971  <p>✅Mô tả:</p><p>👉Đất 98.6m, Mặt tiền = Hậu: 4...               Có Sổ đỏ
# 972  <p>✅ ĐẤT NỞ HẬU - FULL THỔ CƯ - ĐẤT Ở ĐÔ THỊ -...               Có Sổ đỏ
# 973  Khu đất đất là một thung lũng độc lập, có ao, ...               Có Sổ đỏ
# 974  Lô đất bám mặt đường liên xã hơn 20m, sau lưng...               Có Sổ đỏ
# 975  Thông tin chi tiết:\n<br/>Diện tích 1952m2 tro...               Có Sổ đỏ
#
#                      type_estate  province    district  bedroom  toilet floor  \
# 0    Nhà hàng, khách sạn, resort  Hòa Bình   Lương Sơn      NaN     NaN  None
# 1                    Nhà mặt phố    Hà Nội   Hoàn Kiếm      2.0     3.0     4
# 2                 Nhà đất thổ cư    Hà Nội   Thanh Oai      NaN     NaN  None
# 3                 Đất trang trại  Hòa Bình   Lương Sơn      NaN     NaN  None
# 4                 Nhà đất thổ cư    Hà Nội     Hà Đông      3.0     4.0     5
# ..                           ...       ...         ...      ...     ...   ...
# 971               Nhà đất thổ cư    Hà Nội    Đông Anh      1.0     1.0  None
# 972               Nhà đất thổ cư    Hà Nội     Mê Linh      1.0     1.0  None
# 973               Nhà đất thổ cư    Hà Nội  Thạch Thất      NaN     NaN  None
# 974               Nhà đất thổ cư    Hà Nội  Thạch Thất      NaN     NaN  None
# 975               Nhà đất thổ cư  Hòa Bình   Lương Sơn      NaN     NaN  None
#
#     direction entrance_width width  \
# 0        None           None  None
# 1        None         11 (m)     6
# 2        None           None  None
# 3        None           None  None
# 4        None          4 (m)     4
# ..        ...            ...   ...
# 971      None          4 (m)     4
# 972      None          3 (m)     4
# 973      None          7 (m)  None
# 974  Đông nam          7 (m)  None
# 975      None          4 (m)  None
#
#                                            image_links phonenumber  \
# 0    https://nhadat24h.net//Upload/User/DangTin/202...  0926939389
# 1    https://nhadat24h.net//Upload/User/DangTin/202...  0936391186
# 2    https://nhadat24h.net//Upload/User/DangTin/202...  0989124334
# 3    https://nhadat24h.net//Upload/User/DangTin/202...  0926939389
# 4    https://nhadat24h.net/https://nhadat24h01.blob...  0397033017
# ..                                                 ...         ...
# 971  https://nhadat24h.net//Upload/User/DangTin/202...  0567111121
# 972  https://nhadat24h.net//Upload/User/DangTin/202...  0567111121
# 973  https://nhadat24h.net//Upload/User/DangTin/202...  0968028768
# 974  https://nhadat24h.net//Upload/User/DangTin/202...  0968028768
# 975  https://nhadat24h.net//Upload/User/DangTin/202...  0968028768
#
#                               geo_code
# 0                                 None
# 1                                 None
# 2            [20.8837388, 105.7901402]
# 3            [20.9046813, 105.5786736]
# 4                                 None
# ..                                 ...
# 971  [21.18216435, 105.86620032916596]
# 972          [21.2125145, 105.7551218]
# 973                               None
# 974                               None
# 975                               None
#
# [976 rows x 19 columns]

# %%
buydata_df.to_csv('buy_data.csv', encoding='utf-8', index=False)

# %%
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

try:
    with connection.cursor() as cursor:
        # Xóa dữ liệu từ cả hai bảng pools_bds và pools_image
        cursor.execute("""
            DELETE pb, pi
            FROM pools_bds pb
            JOIN pools_image pi ON pb.BDS_id = pi.BDS_id
            WHERE pb.kind = 'Mua Bán' AND pi.content LIKE '%nhadat24h.net%'
        """)
        connection.commit()

finally:
    connection.close()

# %%
import csv
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL với mã hóa utf8mb4
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

def is_decimal(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

try:
    with connection.cursor() as cursor:
        
        # Đọc dữ liệu từ file CSV và nhập vào MySQL
        with open('buy_data.csv', 'r', encoding='utf-8') as file:
            csv_data = csv.DictReader(file)
            for row in csv_data:
                try:
                    district = row['district']
                    province_city = row['province']
                    
                    # Kiểm tra tồn tại address
                    cursor.execute("SELECT address_id FROM pools_address WHERE district = %s AND province_city = %s", (district, province_city))
                    existing_address = cursor.fetchone()
                    if existing_address:
                        address_id = existing_address['address_id']
                    else:
                        # Nếu không tìm thấy địa chỉ, bỏ qua dòng này
                        print(f"Không tìm thấy địa chỉ cho dòng: {row}")
                        continue
                    
                    # Kiểm tra pools_typeofbds 
                    bds_type = row['type_estate']
                    cursor.execute("SELECT Type_Id FROM pools_typeofbds WHERE TypeName = %s", (bds_type,))
                    existing_type = cursor.fetchone()
                    if existing_type:
                        type_id = existing_type['Type_Id']
                    else:
                        # Nếu không tìm thấy loại bất động sản, bỏ qua dòng này
                        print(f"Không tìm thấy loại bất động sản cho dòng: {row}")
                        continue
                    
                    # Thêm dữ liệu vào bảng pools_bds
                    title = row['title']
                    price = row['price']
                    area = row['area']
                    kind = row['type']
                    law = row['law']
                    bedroom = row['bedroom']
                    phonenumber = row['phonenumber']
                    floor = row['floor']
                    description = row['description']
                    width = row['width']
                    direction = row['direction']
                    toilet = row['toilet']
                    location = row['address']
                    geocode = row['geo_code']
                    
                    # Handle 'price' column
                    if price.strip().lower() == 'thỏa thuận':
                        price = 0  # or set to a default value, like 0
                    elif not is_decimal(price):
                        price = 0  # or set to a default value

                    # Handle 'width' column
                    if not is_decimal(width):
                        width = 0  # or set to a default value

                    # Handle 'bedroom' column
                    if not bedroom.strip() or bedroom.lower() == 'null':
                        bedroom = 0  # or set to a default value
                       
                    # Handle 'floor' column 
                    if not floor.strip() or floor.lower() == 'null':
                        floor = 0  # or set to a default value

                    # Handle 'toilet' column (if needed)
                    if not is_decimal(toilet):
                        toilet = 0  # or set to a default value

                    # Kiểm tra geocode nếu là None hoặc rỗng, bỏ qua dòng này
                    if not geocode:
                        # print(f"Không có giá trị geocode cho dòng: {row}")
                        continue

                    # Chuyển geo_code thành string nếu nó là list
                    if isinstance(geocode, list):
                        geocode = str(geocode)

                    # Thêm dữ liệu vào bảng pools_bds
                    cursor.execute("""
                        INSERT INTO pools_bds (title, price, area, kind, law, bedroom, floor, phonenumber, address_id, Type_id, description, width, direction, toilet, location, geocode)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                    """, (title, price, area, kind, law, bedroom, floor, phonenumber, address_id, type_id, description, width, direction, toilet, location, geocode))
                    connection.commit()
                    
                    # Lấy BDS_id của BDS vừa thêm
                    cursor.execute("SELECT LAST_INSERT_ID()")
                    bds_id = cursor.fetchone()['LAST_INSERT_ID()']
                    
                    # Thêm dữ liệu vào bảng pools_image (nếu có)
                    if 'image_links' in row and row['image_links']:  # Kiểm tra xem cột 'image_link' có tồn tại và có giá trị không
                        image_link = row['image_links']
                        cursor.execute("INSERT INTO pools_image (BDS_id, content) VALUES (%s, %s)", (bds_id, image_link))
                        connection.commit()
                        
                except Exception as e:
                    print(f"Lỗi khi xử lý dòng: {row}")
                    print(e)
finally:
    connection.close()
