# %%
import pandas as pd
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError
from geopy.geocoders import Nominatim

buydata_df = pd.read_json('buy_data.json')

# %%
buydata_df
# Out:
#                                                 title  \
# 0                      CẦN BÁN LÔ ĐẤT DÂN CƯ ĐÔNG ĐÚC
# 1   CHÍNH THỨC NHẬN BOOKING TÒA G2 - PHÂN KHU GIÁ ...
# 2   Vốn chỉ 680 triệu sở hữu nhà phố biệt lập The ...
# 3   Căn hộ cao ốc A Ngô Gia Tự, Quận 10 73m2, 2 ph...
# 4   Cần bán lô đất view hồ khu đấu giá Thị trấn ...
# 5    Cần bán nhà 70m2 đường Cao Thắng, Quận Phú Nhuận
# 6   Bán nhà Ngọc Lâm, Long Biên 58m2, 6 tầng, gara...
# 7   Bán nhà Phúc Đồng, sân golf Long Biên 86m2, 4 ...
# 8   Bán nhà Phúc Đồng, Long Biên, 86m2, 7 tầng, mặ...
# 9   Giảm sốc 800 triệu bán nhà Nguyễn Văn Cừ, Long...
# 10                  Cần nhượng lại đất ấp 5 phong phú
# 11  Giá 2tỷ6/68m2.Bán nhà 1Trệt 1Lầu thích hợp cô ...
# 12                                    Đất ngộp eakmat
#
#                                               address         price  \
# 0                             H. Bến Cầu, T. Tây Ninh     420 Triệu
# 1   Vinhomes Smart City, P. Đại Mỗ, Q. Nam Từ Liêm...        3,5 Tỷ
# 2   Đ. 10, P. Tân Phước Khánh, Tx. Tân Uyên, T. Bì...        3,8 Tỷ
# 3       Đ. Sư Vạn Hạnh, P. 02, Q. 10, Tp. Hồ Chí Minh        3,4 Tỷ
# 4   Đ. Quốc Lộ 10, Tt. An Bài, H. Quỳnh Phụ, T. Th...       2,05 Tỷ
# 5   77, Đ. Cao Thắng, P. 17, Q. Phú Nhuận, Tp. Hồ ...         10 Tỷ
# 6   Đ. Ngọc Lâm, P. Ngọc Lâm, Q. Long Biên, Tp. Hà...       11,8 Tỷ
# 7   Đ. Phúc Đồng, P. Phúc Đồng, Q. Long Biên, Tp. ...       11,5 Tỷ
# 8   Đ. Phúc Đồng, P. Phúc Đồng, Q. Long Biên, Tp. ...       15,5 Tỷ
# 9   Đ. Nguyễn Văn Cừ, P. Bồ Đề, Q. Long Biên, Tp. ...       11,6 Tỷ
# 10  Đ. Bờ Bao, X. Phong Phú, H. Bình Chánh, Tp. Hồ...  649,99 Triệu
# 11            Đ. Tản Đà, P. 11, Q. 5, Tp. Hồ Chí Minh       2,79 Tỷ
# 12        X. Hòa Thắng, Tp. Buôn Ma Thuột, T. Đắk Lắk  640,07 Triệu
#
#                                           description      type_estate  \
# 0   Diện tích: 5 x 29.Thổ cư: 50m2.Đất thuộc Long ...              Đất
# 1   Phân khu giá rẻ nhất còn lại tại Vinhomes Smar...  Căn hộ chung cư
# 2   Vốn chỉ 680 triệu sở hữu nhà phố biệt lập The ...      Nhà mặt phố
# 3   Cần bán căn nhà ở cao ốc Ngô Gia Tự, phường 02...  Căn hộ chung cư
# 4   LK13-34 mặt view hồ cực thoáng mát kinh doanh ...              Đất
# 5   Bán nhà riêng số 77 Cao Thắng, Phường 17, Phú ...        Nhà riêng
# 6   * Vị trí nhà nằm ngay phố ẩm thực Ngọc Lâm, gầ...        Nhà riêng
# 7   * Nhà nằm trong khu phân lô quân đội 918, gần ...        Nhà riêng
# 8   * Nhà nằm trong khu phân lô quân đội 918, khu ...        Nhà riêng
# 9   Bán nhà Nguyễn Văn Cừ, Long Biên 60m2, 5 tầng,...        Nhà riêng
# 10  Mình co mảnh đất 43m ở ấp 5 xa phong phú cần n...              Đất
# 11  Bán gấp nhà 1Trệt 1Lầu cực đẹp thích hợp với c...        Nhà riêng
# 12  Lô Ea Kmat- hoà đông thông hồ cuoor kắp- sân b...              Đất
#
#        type     area  bedroom  toilet  \
# 0   Mua Bán   146 m²      NaN     NaN
# 1   Mua Bán    55 m²      2.0     2.0
# 2   Mua Bán    85 m²      NaN     NaN
# 3   Mua Bán    73 m²      2.0     2.0
# 4   Mua Bán   108 m²      NaN     NaN
# 5   Mua Bán  68.8 m²      4.0     3.0
# 6   Mua Bán    58 m²      4.0     4.0
# 7   Mua Bán    86 m²      4.0     4.0
# 8   Mua Bán    86 m²      5.0     5.0
# 9   Mua Bán    60 m²      4.0     4.0
# 10  Mua Bán    43 m²      NaN     NaN
# 11  Mua Bán    35 m²      3.0     3.0
# 12  Mua Bán   373 m²      NaN     NaN
#
#                                                   law  \
# 0                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 1                                    Hợp đồng mua bán
# 2                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 3                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 4   Giấy CN QSDĐ, Sổ đỏ, Sổ hồng, Đang làm giấy CN...
# 5                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 6                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 7                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 8                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 9                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 10                       Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 11                       Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
# 12                       Giấy CN QSDĐ, Sổ đỏ, Sổ hồng
#
#                    direction  width  floor  \
# 0                       None    5 m    NaN
# 1                   Đông Nam   None    NaN
# 2                       None   None    NaN
# 3   Đông, Đông Nam, Nam, Bắc   None    NaN
# 4                       None   None    NaN
# 5                       None    5 m    3.0
# 6                       None    4 m    6.0
# 7                       None    5 m    4.0
# 8                       None    5 m    7.0
# 9                       None  4.2 m    5.0
# 10                      None   None    NaN
# 11                      None  4.5 m    NaN
# 12                      None    5 m    NaN
#
#                                           image_links
# 0   https://i.meeymedia.com/4IPu5JH0hY7CJeTlLQd8Pl...
# 1   https://io.meeymedia.com/meeyland/images/2024/...
# 2   https://io.meeymedia.com/meeyland/images/2024/...
# 3   https://io.meeymedia.com/meeyland/images/2024/...
# 4   https://io.meeymedia.com/meeyland/images/2024/...
# 5   https://static.meeyland.com/articles/z52031016...
# 6   https://io.meeymedia.com/meeyland/images/2024/...
# 7   https://io.meeymedia.com/meeyland/images/2024/...
# 8   https://io.meeymedia.com/meeyland/images/2024/...
# 9   https://i.meeymedia.com/T5zj7afnU-kvLr0sDvD98y...
# 10  https://i.meeymedia.com/29iXt1HaumZCa3C4e1Clo2...
# 11  https://i.meeymedia.com/VPjOVNwiZrjv9ch-UJi3MF...
# 12  https://i.meeymedia.com/r49J7M_HkmdqVs7LvksV9K...

# %%
title = []                  # 1
price = []                  # 2
area = []                   # 3
bedroom = []        # 4
description = []            # 5
width = []                  # 6
direction = []              # 7
toilet = []         # 8
address = []               # 9
geo_code = []               # 10
law = []
floor = []
district = []
province_city = []
type = []
type_estate = []
image_links = []

# %%
import requests
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError
import pandas as pd

# Add new column with default None values for geocodes
buydata_df["geo_code"] = [None for _ in range(len(buydata_df))]

def get_geocode(address):
    api_key = 'b48b7a0d92434d7ba9e13d0feb2db0ad'
    url = f"https://api.opencagedata.com/geocode/v1/json?q={address}&key={api_key}"

    response = requests.get(url)
    data = response.json()

    if data['results']:
        latitude = data['results'][0]['geometry']['lat']
        longitude = data['results'][0]['geometry']['lng']
        print(f"Latitude: {latitude}, Longitude: {longitude}")
        return [latitude, longitude]
    else:
        # Check if address contains "Đường"
        if "Đường" in address:
            # Remove "Đường" and retry
            modified_address = address.replace("Đường", "").strip()
            print(f"Retry with modified address: {modified_address}")
            return get_geocode(modified_address)
        else:
            print("No results found.")
            return None
        
if 'address' in buydata_df.columns:
    for i, address in enumerate(buydata_df["address"]):
        buydata_df.at[i, "geo_code"] = get_geocode(address)
else:
    print("Error: 'address' column not found in the DataFrame.")

def data_normalization(df):    
    for i, address in enumerate(df["address"]):
        df.at[i, "geo_code"] = get_geocode(address)
        district, province_city = extract_district_and_province(address)
        df.at[i, "district"] = district.replace("Q.", '').replace("H.", '').replace("Tp.", '').replace("Tx.", '').strip()    
        df.at[i, "province_city"] = province_city.replace("Tp.", '').replace("T.", '').strip()     
        
    for i, price in enumerate(df['price']):
        # Loại bỏ khoảng trắng thừa
        price = price.strip()
        
        # Thay thế dấu phẩy bằng dấu chấm
        price = price.replace(',', '.')
        
        # Kiểm tra và xử lý nếu tồn tại từ 'Triệu'
        if 'Triệu' in price:
            # Loại bỏ từ 'Triệu' và khoảng trắng
            price = price.replace('Triệu', '').strip()
            # Chuyển đổi giá trị thành tỷ
            price = float(price) / 1000  # Chia cho 1000 để đổi từ triệu thành tỷ
        # Kiểm tra và xử lý nếu tồn tại từ 'Tỷ'
        elif 'Tỷ' in price:
            price = price.replace('Tỷ', '').strip()
            # Chuyển đổi giá trị thành float
            price = float(price)
        else:
            # Loại bỏ các dấu chấm ngăn cách phần nghìn, triệu (nếu có)
            if '.' in price and price.count('.') > 1:
                price = price.replace('.', '', price.count('.') - 1)           
            

        # Gán lại giá trị vào dataframe
        df.at[i, 'price'] = price
    for i, width in enumerate(df['width']):
        if isinstance(width, str):
            df.at[i, "width"] = width.replace("m", '').strip()
        
    for i, area in enumerate(df['area']):
        if isinstance(area, str):
            df.at[i, "area"] = area.replace("m", '').replace("²", '').strip()
    
    for i, direction in enumerate(df['direction']):
        if isinstance(direction, str):
            df.at[i, "direction"] = direction.split(',')[0].strip() 

def extract_district_and_province(address):
    parts = address.split(',')
    if len(parts) >= 2:
        district = parts[-2].strip()
        province_city = parts[-1].strip()
        return district, province_city
    return None, None

data_normalization(buydata_df)

buydata_df['type_estate'] = buydata_df['type_estate'].replace({
    'Nhà mặt phố': 'Nhà Mặt Phố',
    'Biệt thự': 'Nhà Biệt Thự, Liền Kề',
    'Liền kề': 'Nhà Biệt Thự, Liền Kề',
    'Chung cư mini': 'Căn Hộ Chung Cư',
    'Căn hộ chung cư': 'Căn Hộ Chung Cư',
    'Nhà tập thể': 'Căn Hộ Chung Cư',
    'Đất': 'Nhà Đất Thổ Cư',
    'Nhà riêng': 'Nhà Đất Thổ Cư',
    'Đất nền dự án': 'Đất Nền Dự Án',
    'Dự án BĐS': 'Đất Nền Dự Án',
    'Nhà trọ': 'Nhà Trọ, Phòng Trọ',
    'Phòng trọ': 'Nhà Trọ, Phòng Trọ',
    'Khách sạn - Nhà nghỉ': 'Nhà Hàng, Khách Sạn, Resort',
    'Căn hộ dịch vụ - Homestay': 'Nhà Hàng, Khách Sạn, Resort',
    'Khu nghỉ dưỡng - Resort': 'Nhà Hàng, Khách Sạn, Resort',
    'Căn hộ khách sạn - Condotel': 'Condotel',
    'Căn hộ văn phòng - Officetel': 'OficeTel',    
    'Nhà phố thương mại - Shophouse': 'ShopHouse',
    'Tòa nhà văn phòng': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Văn phòng Co-working': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Trang trại': 'Đất Trang Trại',
    'Văn phòng': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Nhà hàng - Cửa hàng - Kiot': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Mặt bằng': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Xưởng sản xuất thực phẩm': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
    'Kho bãi - Nhà xưởng - Khu công nghiệp': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
    'Mặt bằng': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
    'Đất trống': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
})

def write_data(df, field, data_list):
    if not isinstance(data_list, list):
        data_list = []  # Initialize as empty list if not already
    
    if field in df.columns:
        for value in df[field]:
            data_list.append(value)
    else:
        print(f"Error: '{field}' column not found in the DataFrame.")

write_data(buydata_df, "title", title)
write_data(buydata_df, "price", price)
write_data(buydata_df, "area", area)
write_data(buydata_df, "type", type)
write_data(buydata_df, "type_estate", type_estate)
write_data(buydata_df, "image_links", image_links)
write_data(buydata_df, "bedroom", bedroom)
write_data(buydata_df, "description", description)
write_data(buydata_df, "width", width)
write_data(buydata_df, "direction", direction)
write_data(buydata_df, "toilet", toilet)
write_data(buydata_df, "address", address)
write_data(buydata_df, "law", law)
write_data(buydata_df, "floor", floor)
write_data(buydata_df, "geo_code", geo_code)
write_data(buydata_df, "district", district)
write_data(buydata_df, "province_city", province_city)

# Display the updated DataFrame
print("\nUpdated DataFrame:")
# Out:
# Latitude: 11.31004, Longitude: 106.09828
# Latitude: 37.83333, Longitude: 12.66667
# Latitude: 10.8268739, Longitude: 106.7311806
# Latitude: 10.7628018, Longitude: 106.6726569
# Latitude: 20.65095, Longitude: 106.36359
# Latitude: 10.7932463, Longitude: 106.6828262
# Latitude: 21.0478752, Longitude: 105.874573
# Latitude: 21.0413879, Longitude: 105.9013569
# Latitude: 21.0413879, Longitude: 105.9013569
# Latitude: 21.0411658, Longitude: 105.8693654
# Latitude: 37.83333, Longitude: 12.66667
# Latitude: 10.7547116, Longitude: 106.6639157
# Latitude: 12.75, Longitude: 108.25
# Latitude: 11.31004, Longitude: 106.09828
# Latitude: 37.83333, Longitude: 12.66667
# Latitude: 10.8268739, Longitude: 106.7311806
# Latitude: 10.7628018, Longitude: 106.6726569
# Latitude: 20.65095, Longitude: 106.36359
# Latitude: 10.7932463, Longitude: 106.6828262
# Latitude: 21.0478752, Longitude: 105.874573
# Latitude: 21.0413879, Longitude: 105.9013569
# Latitude: 21.0413879, Longitude: 105.9013569
# Latitude: 21.0411658, Longitude: 105.8693654
# Latitude: 37.83333, Longitude: 12.66667
# Latitude: 10.7547116, Longitude: 106.6639157
# Latitude: 12.75, Longitude: 108.25
#
# Updated DataFrame:

# %%
buydata_df
# Out:
#                                                 title  \
# 0                      CẦN BÁN LÔ ĐẤT DÂN CƯ ĐÔNG ĐÚC
# 1   CHÍNH THỨC NHẬN BOOKING TÒA G2 - PHÂN KHU GIÁ ...
# 2   Vốn chỉ 680 triệu sở hữu nhà phố biệt lập The ...
# 3   Căn hộ cao ốc A Ngô Gia Tự, Quận 10 73m2, 2 ph...
# 4   Cần bán lô đất view hồ khu đấu giá Thị trấn ...
# 5    Cần bán nhà 70m2 đường Cao Thắng, Quận Phú Nhuận
# 6   Bán nhà Ngọc Lâm, Long Biên 58m2, 6 tầng, gara...
# 7   Bán nhà Phúc Đồng, sân golf Long Biên 86m2, 4 ...
# 8   Bán nhà Phúc Đồng, Long Biên, 86m2, 7 tầng, mặ...
# 9   Giảm sốc 800 triệu bán nhà Nguyễn Văn Cừ, Long...
# 10                  Cần nhượng lại đất ấp 5 phong phú
# 11  Giá 2tỷ6/68m2.Bán nhà 1Trệt 1Lầu thích hợp cô ...
# 12                                    Đất ngộp eakmat
#
#                                               address    price  \
# 0                             H. Bến Cầu, T. Tây Ninh     0.42
# 1   Vinhomes Smart City, P. Đại Mỗ, Q. Nam Từ Liêm...      3.5
# 2   Đ. 10, P. Tân Phước Khánh, Tx. Tân Uyên, T. Bì...      3.8
# 3       Đ. Sư Vạn Hạnh, P. 02, Q. 10, Tp. Hồ Chí Minh      3.4
# 4   Đ. Quốc Lộ 10, Tt. An Bài, H. Quỳnh Phụ, T. Th...     2.05
# 5   77, Đ. Cao Thắng, P. 17, Q. Phú Nhuận, Tp. Hồ ...     10.0
# 6   Đ. Ngọc Lâm, P. Ngọc Lâm, Q. Long Biên, Tp. Hà...     11.8
# 7   Đ. Phúc Đồng, P. Phúc Đồng, Q. Long Biên, Tp. ...     11.5
# 8   Đ. Phúc Đồng, P. Phúc Đồng, Q. Long Biên, Tp. ...     15.5
# 9   Đ. Nguyễn Văn Cừ, P. Bồ Đề, Q. Long Biên, Tp. ...     11.6
# 10  Đ. Bờ Bao, X. Phong Phú, H. Bình Chánh, Tp. Hồ...  0.64999
# 11            Đ. Tản Đà, P. 11, Q. 5, Tp. Hồ Chí Minh     2.79
# 12        X. Hòa Thắng, Tp. Buôn Ma Thuột, T. Đắk Lắk  0.64007
#
#                                           description      type_estate  \
# 0   Diện tích: 5 x 29.Thổ cư: 50m2.Đất thuộc Long ...   Nhà Đất Thổ Cư
# 1   Phân khu giá rẻ nhất còn lại tại Vinhomes Smar...  Căn Hộ Chung Cư
# 2   Vốn chỉ 680 triệu sở hữu nhà phố biệt lập The ...      Nhà Mặt Phố
# 3   Cần bán căn nhà ở cao ốc Ngô Gia Tự, phường 02...  Căn Hộ Chung Cư
# 4   LK13-34 mặt view hồ cực thoáng mát kinh doanh ...   Nhà Đất Thổ Cư
# 5   Bán nhà riêng số 77 Cao Thắng, Phường 17, Phú ...   Nhà Đất Thổ Cư
# 6   * Vị trí nhà nằm ngay phố ẩm thực Ngọc Lâm, gầ...   Nhà Đất Thổ Cư
# 7   * Nhà nằm trong khu phân lô quân đội 918, gần ...   Nhà Đất Thổ Cư
# 8   * Nhà nằm trong khu phân lô quân đội 918, khu ...   Nhà Đất Thổ Cư
# 9   Bán nhà Nguyễn Văn Cừ, Long Biên 60m2, 5 tầng,...   Nhà Đất Thổ Cư
# 10  Mình co mảnh đất 43m ở ấp 5 xa phong phú cần n...   Nhà Đất Thổ Cư
# 11  Bán gấp nhà 1Trệt 1Lầu cực đẹp thích hợp với c...   Nhà Đất Thổ Cư
# 12  Lô Ea Kmat- hoà đông thông hồ cuoor kắp- sân b...   Nhà Đất Thổ Cư
#
#        type  area  bedroom  toilet  \
# 0   Mua Bán   146      NaN     NaN
# 1   Mua Bán    55      2.0     2.0
# 2   Mua Bán    85      NaN     NaN
# 3   Mua Bán    73      2.0     2.0
# 4   Mua Bán   108      NaN     NaN
# 5   Mua Bán  68.8      4.0     3.0
# 6   Mua Bán    58      4.0     4.0
# 7   Mua Bán    86      4.0     4.0
# 8   Mua Bán    86      5.0     5.0
# 9   Mua Bán    60      4.0     4.0
# 10  Mua Bán    43      NaN     NaN
# 11  Mua Bán    35      3.0     3.0
# 12  Mua Bán   373      NaN     NaN
#
#                                                   law direction width  floor  \
# 0                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None     5    NaN
# 1                                    Hợp đồng mua bán  Đông Nam  None    NaN
# 2                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None  None    NaN
# 3                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      Đông  None    NaN
# 4   Giấy CN QSDĐ, Sổ đỏ, Sổ hồng, Đang làm giấy CN...      None  None    NaN
# 5                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None     5    3.0
# 6                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None     4    6.0
# 7                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None     5    4.0
# 8                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None     5    7.0
# 9                        Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None   4.2    5.0
# 10                       Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None  None    NaN
# 11                       Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None   4.5    NaN
# 12                       Giấy CN QSDĐ, Sổ đỏ, Sổ hồng      None     5    NaN
#
#                                           image_links  \
# 0   https://i.meeymedia.com/4IPu5JH0hY7CJeTlLQd8Pl...
# 1   https://io.meeymedia.com/meeyland/images/2024/...
# 2   https://io.meeymedia.com/meeyland/images/2024/...
# 3   https://io.meeymedia.com/meeyland/images/2024/...
# 4   https://io.meeymedia.com/meeyland/images/2024/...
# 5   https://static.meeyland.com/articles/z52031016...
# 6   https://io.meeymedia.com/meeyland/images/2024/...
# 7   https://io.meeymedia.com/meeyland/images/2024/...
# 8   https://io.meeymedia.com/meeyland/images/2024/...
# 9   https://i.meeymedia.com/T5zj7afnU-kvLr0sDvD98y...
# 10  https://i.meeymedia.com/29iXt1HaumZCa3C4e1Clo2...
# 11  https://i.meeymedia.com/VPjOVNwiZrjv9ch-UJi3MF...
# 12  https://i.meeymedia.com/r49J7M_HkmdqVs7LvksV9K...
#
#                      geo_code       district province_city
# 0       [11.31004, 106.09828]        Bến Cầu      Tây Ninh
# 1        [37.83333, 12.66667]    Nam Từ Liêm        Hà Nội
# 2   [10.8268739, 106.7311806]       Tân Uyên    Bình Dương
# 3   [10.7628018, 106.6726569]             10   Hồ Chí Minh
# 4       [20.65095, 106.36359]      Quỳnh Phụ     Thái Bình
# 5   [10.7932463, 106.6828262]      Phú Nhuận   Hồ Chí Minh
# 6    [21.0478752, 105.874573]      Long Biên        Hà Nội
# 7   [21.0413879, 105.9013569]      Long Biên        Hà Nội
# 8   [21.0413879, 105.9013569]      Long Biên        Hà Nội
# 9   [21.0411658, 105.8693654]      Long Biên        Hà Nội
# 10       [37.83333, 12.66667]     Bình Chánh   Hồ Chí Minh
# 11  [10.7547116, 106.6639157]              5   Hồ Chí Minh
# 12            [12.75, 108.25]  Buôn Ma Thuột       Đắk Lắk

# %%
buydata_df.to_csv('buy_data.csv', encoding='utf-8', index=False)

# %%
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

try:
    with connection.cursor() as cursor:
        # Xóa dữ liệu từ cả hai bảng pools_bds và pools_image
        cursor.execute("""
            DELETE pb, pi
            FROM pools_bds pb
            JOIN pools_image pi ON pb.BDS_id = pi.BDS_id
            WHERE pb.kind = 'Mua Bán' AND pi.content LIKE '%.meey%'
        """)
        connection.commit()

finally:
    connection.close()

# %%
import csv
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL với mã hóa utf8mb4
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

def is_decimal(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

try:
    with connection.cursor() as cursor:
        
        # Đọc dữ liệu từ file CSV và nhập vào MySQL
        with open('buy_data.csv', 'r', encoding='utf-8') as file:
            csv_data = csv.DictReader(file)
            for row in csv_data:
                try:
                    district = row['district']
                    province_city = row['province_city']
                    
                    # Kiểm tra tồn tại address
                    cursor.execute("SELECT address_id FROM pools_address WHERE district = %s AND province_city = %s", (district, province_city))
                    existing_address = cursor.fetchone()
                    if existing_address:
                        address_id = existing_address['address_id']
                    else:
                        # Nếu không tìm thấy địa chỉ, bỏ qua dòng này
                        print(f"Không tìm thấy địa chỉ cho dòng: {row}")
                        continue
                    
                    # Kiểm tra pools_typeofbds 
                    bds_type = row['type_estate']
                    cursor.execute("SELECT Type_Id FROM pools_typeofbds WHERE TypeName = %s", (bds_type,))
                    existing_type = cursor.fetchone()
                    if existing_type:
                        type_id = existing_type['Type_Id']
                    else:
                        # Nếu không tìm thấy loại bất động sản, bỏ qua dòng này
                        print(f"Không tìm thấy loại bất động sản cho dòng: {row}")
                        continue
                    
                    # Thêm dữ liệu vào bảng pools_bds
                    title = row['title']
                    price = row['price']
                    area = row['area']
                    kind = row['type']
                    law = row['law']
                    bedroom = row['bedroom']
                    floor = row['floor']
                    description = row['description']
                    width = row['width']
                    direction = row['direction']
                    toilet = row['toilet']
                    location = row['address']
                    geocode = row['geo_code']
                    
                    # Handle 'price' column
                    if price.strip().lower() == 'thỏa thuận':
                        price = 0  # or set to a default value, like 0
                    elif not is_decimal(price):
                        price = 0  # or set to a default value

                    # Handle 'width' column
                    if not is_decimal(width):
                        width = 0  # or set to a default value

                    # Handle 'bedroom' column
                    if not bedroom.strip() or bedroom.lower() == 'null':
                        bedroom = 0  # or set to a default value
                       
                    # Handle 'floor' column 
                    if not floor.strip() or floor.lower() == 'null':
                        floor = 0  # or set to a default value

                    # Handle 'toilet' column (if needed)
                    if not is_decimal(toilet):
                        toilet = 0  # or set to a default value

                    # Kiểm tra geocode nếu là None hoặc rỗng, bỏ qua dòng này
                    if not geocode:
                        # print(f"Không có giá trị geocode cho dòng: {row}")
                        continue

                    # Chuyển geo_code thành string nếu nó là list
                    if isinstance(geocode, list):
                        geocode = str(geocode)

                    # Thêm dữ liệu vào bảng pools_bds
                    cursor.execute("""
                        INSERT INTO pools_bds (title, price, area, kind, law, bedroom, floor, address_id, Type_id, description, width, direction, toilet, location, geocode)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                    """, (title, price, area, kind, law, bedroom, floor, address_id, type_id, description, width, direction, toilet, location, geocode))
                    connection.commit()
                    
                    # Lấy BDS_id của BDS vừa thêm
                    cursor.execute("SELECT LAST_INSERT_ID()")
                    bds_id = cursor.fetchone()['LAST_INSERT_ID()']
                    
                    # Thêm dữ liệu vào bảng pools_image (nếu có)
                    if 'image_links' in row and row['image_links']:  # Kiểm tra xem cột 'image_link' có tồn tại và có giá trị không
                        image_link = row['image_links']
                        cursor.execute("INSERT INTO pools_image (BDS_id, content) VALUES (%s, %s)", (bds_id, image_link))
                        connection.commit()
                        
                except Exception as e:
                    print(f"Lỗi khi xử lý dòng: {row}")
                    print(e)
finally:
    connection.close()
# Out:
# Lỗi khi xử lý dòng: {'title': 'Bán nhà Phúc Đồng, sân golf Long Biên 86m2, 4 tầng, mặt tiền 5m, gara, full nội thất, phân lô, đầu tư', 'address': 'Đ. Phúc Đồng, P. Phúc Đồng, Q. Long Biên, Tp. Hà Nội', 'price': '11.5', 'description': '* Nhà nằm trong khu phân lô quân đội 918, gần sân golf Long Biên, Khu phân lô cho cán bộ Quân đội, đường trước nhà rộng thoáng, 2 ô tô tránh.\n* Vị trí giao thông thuận tiện di chuyển đi khắp các hướng như Tư Đình, Sài Đồng, Nguyễn Lam, Thạch Bàn, Phố Trạm. Mấy phút đến đại siêu thị Aeon Long Biên, Trung tâm Vincom Center, Khu đô thị Sài Đồng, Tổ Hợp biệt thự HimLam.\n* Nhà thiết kế hiện đại 4 tầng có gara, nội thất cao cấp, các phòng đều có thoáng sáng tự nhiên.\n* Sổ đỏ chính chủ, pháp lý chuẩn, sẵn sàng giao dịch ngay.\n* Giá bán: 11.5 tỷ (Có thương lượng).\n* LH E Dũng 0972106017 chuyên thổ cư Long Biên. Hỗ trợ, tư vấn, xem nhà và gặp chủ miễn phí.', 'type_estate': 'Nhà Đất Thổ Cư', 'type': 'Mua Bán', 'area': '86', 'bedroom': '4.0', 'toilet': '4.0', 'law': 'Giấy CN QSDĐ, Sổ đỏ, Sổ hồng', 'direction': '', 'width': '5', 'floor': '4.0', 'image_links': 'https://io.meeymedia.com/meeyland/images/2024/05/23/z546405329170968fb6aef5ff5db8cdfb07e1c3af23fc21716438187814-1716438190685.jpg?d=900x600', 'geo_code': '[21.0413879, 105.9013569]', 'district': 'Long Biên', 'province_city': 'Hà Nội'}
# (1406, "Data too long for column 'title' at row 1")
