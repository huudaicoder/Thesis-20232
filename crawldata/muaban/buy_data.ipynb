# %%
import pandas as pd
import json
import time
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError
from geopy.geocoders import Nominatim

buydata_df = pd.read_json('buy_data.json')

# %%
buydata_df
# Out:
#                                                  title            price  \
# 0    Bán nhà Gò Vấp, Thống Nhất, P.11, sàn 121,4m2,...   5 tỷ 700 triệu
# 1    Bán nhà mặt đường ngã ba Ngọc Khánh, Kim Mã, 3...  13 tỷ 800 triệu
# 2    Bán đất Quốc Oai, Hà Nội, gần Nhà máy tin tiền...    123.456.789 đ
# 3    Nhà Dương Quãng Hàm P6 ( 1 trệt 1 lững 4 lầu )...  12 tỷ 500 triệu
# 4    Xuất cảnh cần bán gấp Nhà Biệt Thự Tân Hiệp Hó...  18 tỷ 500 triệu
# ..                                                 ...              ...
# 166  CHỈ 1,9 TỶ CÓ DTS 40M2 - KHÔNG QH - SỔ HỒNG RI...   1 tỷ 900 triệu
# 167  Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Câ...             6 tỷ
# 168  Cần bán 100 m2 đất, mặt tiền 5m, tại Đông Mỹ, ...    123.456.789 đ
# 169  Bán nhà số 51B ngõ 383 phố Phúc Tân, phường Ph...   5 tỷ 300 triệu
# 170  BÁN NHÀ GÓC 3 MẶT TIỀN, VỊ TRÍ SẦM UẤT BẬC I P...            30 tỷ
#
#                    area                                            address  \
# 0               61,3 m²   Đường Thống Nhất, Phường 11, Quận Gò Vấp, TP.HCM
# 1               36,5 m²  Đường Ngọc Khánh, Phường Kim Mã, Quận Ba Đình,...
# 2                600 m²   Đường DH09, Xã Hòa Thạch, Huyện Quốc Oai, Hà Nội
# 3      69 m² (4,2x17,0)  Đường Dương Quảng Hàm, Phường 6, Quận Gò Vấp, ...
# 4    430 m² (14,0x32,0)  4/7H, Đường Tân Hiệp 19, Xã Tân Hiệp, Huyện Hó...
# ..                  ...                                                ...
# 166               20 m²  Đường Nguyễn Sỹ Sách, Phường 15, Quận Tân Bình...
# 167   109 m² (4,1x30,0)  1161, Đường Kha Vạn Cân, Phường Linh Trung, TP...
# 168              100 m²  Đường Phân Lân - 105, Xã Đông Mỹ, Huyện Thanh ...
# 169               46 m²  Số 51B ngõ 383, Đường Phúc Tân, Phường Phúc Tâ...
# 170  67,5 m² (4,5x17,0)  67/1, Đường Lê Đức Thọ, Phường 6, Quận Gò Vấp,...
#
#                                            description     type  \
# 0    BÁN NHÀ ĐƯỜNG THỐNG NHẤT P11 GÒ VẤP gần bệnh v...  Mua Bán
# 1    Bán nhà mặt đường ngã ba Ngọc Khánh, Kim Mã, n...  Mua Bán
# 2    Chính chủ bán đất xã Hòa Thạch + xã Phú Cát, Q...  Mua Bán
# 3    - Nhà P6 Dương Quãng hàm Hẻm Thông 1 xẹt xe hơ...  Mua Bán
# 4    Nhà hướng Nam 1 trệt 1 lầu xây dựng kiên cố, t...  Mua Bán
# ..                                                 ...      ...
# 166  BÁN NHÀ Nguyễn Sỹ Sách, phường 15, quận Tân Bì...  Mua Bán
# 167  Chính chủ bán gấp nhà mặt tiền số 1161 khu phố...  Mua Bán
# 168  Cần bán 100 m2 đất, mặt tiền 5m, tại Đông Mỹ, ...  Mua Bán
# 169  Bán nhà số 51B ngõ 383 phố Phúc Tân, phường Ph...  Mua Bán
# 170  Bán nhà góc 3 mặt tiền tại số 67/1 Lê Đức Thọ,...  Mua Bán
#
#          type_estate      law  floor   bedroom toilet direction  \
# 0       Nhà hẻm, ngõ  Sổ hồng    3.0   3 phòng   3 WC      None
# 1       Nhà mặt tiền    Sổ đỏ    NaN      None   None      None
# 2               None    Sổ đỏ    NaN      None   None      None
# 3       Nhà hẻm, ngõ  Sổ hồng    5.0   6 phòng   7 WC      None
# 4    Biệt thự, Villa  Sổ hồng    2.0      None   None       Nam
# ..               ...      ...    ...       ...    ...       ...
# 166     Nhà hẻm, ngõ  Sổ hồng    NaN   2 phòng   2 WC      None
# 167     Nhà mặt tiền  Sổ hồng    NaN      None   None      None
# 168             None    Sổ đỏ    NaN      None   None      None
# 169     Nhà hẻm, ngõ    Sổ đỏ    4.0      None   None      None
# 170     Nhà hẻm, ngõ  Sổ hồng    7.0  20 phòng  21 WC       Bắc
#
#                                            image_links
# 0    https://cloud.muaban.net/images/thumb-detail/2...
# 1    https://cloud.muaban.net/images/thumb-detail/2...
# 2    https://cloud.muaban.net/images/thumb-detail/2...
# 3    https://cloud.muaban.net/images/thumb-detail/2...
# 4    https://cloud.muaban.net/images/thumb-detail/2...
# ..                                                 ...
# 166  https://cloud.muaban.net/images/thumb-detail/2...
# 167  https://cloud.muaban.net/images/thumb-detail/2...
# 168  https://cloud.muaban.net/images/thumb-detail/2...
# 169  https://cloud.muaban.net/images/thumb-detail/2...
# 170  https://cloud.muaban.net/images/thumb-detail/2...
#
# [171 rows x 13 columns]

# %%
title = []                  # 1
price = []                  # 2
area = []                   # 3
bedroom = []        # 4
description = []            # 5
width = []                  # 6
direction = []              # 7
toilet = []         # 8
address = []               # 9
geo_code = []               # 10
law = []
floor = []
district = []
province_city = []
type = []
type_estate = []
image_links = []
phonenumber = []

# %%
import requests
import re
import pandas as pd

buydata_df["geo_code"] = [None for _ in range(len(buydata_df))]
buydata_df["width"] = [None for _ in range(len(buydata_df))]
buydata_df["direction"] = [None for _ in range(len(buydata_df))]
buydata_df["district"] = [None for _ in range(len(buydata_df))]
buydata_df["province_city"] = [None for _ in range(len(buydata_df))]

def get_geocode(address):
    api_key = 'b48b7a0d92434d7ba9e13d0feb2db0ad'
    url = f"https://api.opencagedata.com/geocode/v1/json?q={address}&key={api_key}"

    response = requests.get(url)
    data = response.json()

    if data['results']:
        latitude = data['results'][0]['geometry']['lat']
        longitude = data['results'][0]['geometry']['lng']
        print(f"Latitude: {latitude}, Longitude: {longitude}")
        return [latitude, longitude]
    else:
        # Check if address contains "Đường"
        if "Đường" in address:
            # Remove "Đường" and retry
            modified_address = address.replace("Đường", "").strip()
            print(f"Retry with modified address: {modified_address}")
            return get_geocode(modified_address)
        else:
            print("No results found.")
            return None

def data_normalization(df):
    for i, address in enumerate(df["address"]):
        df.at[i, "geo_code"] = get_geocode(address)
        district, province_city = extract_district_and_province(address)
        if district == 'Thủ Đức -  Thủ Đức':
            district = 'Thủ Đức'
        df.at[i, "district"] = district.replace('Huyện', '').replace('Quận', '').replace('TP.', '').strip()
        if province_city == 'TP.HCM':
            province_city = 'Hồ Chí Minh'
            
        df.at[i, "province_city"] = province_city
        
    for i, price in enumerate(df['price']):
        if 'triệu' in price:
            if 'tỷ' in price:
                df.at[i, 'price'] = str(round(int(price.split()[0]) + int(price.split()[2]) / 1000, 2))
            else:
                df.at[i, 'price'] = str(round(int(price.split()[0]) / 1000, 2))
        else:
            df.at[i, 'price'] = price.replace(' tỷ', '').strip()    
            
    for i, toilet in enumerate(df['toilet']):
        if isinstance(toilet, str):
         df.at[i, 'toilet'] = toilet.replace(' WC', '').strip()
        
    for i, bedroom in enumerate(df['bedroom']):        
        if isinstance(bedroom, str):
            df.at[i, 'bedroom'] = bedroom.replace(' phòng', '').strip()
    
    for i, area in enumerate(df['area']):
        if area is not None:
            # Split the area string to extract the width
            parts = area.split('(')
            if len(parts) > 1:
                width_part = parts[1].split('x')[0].strip().replace(',', '.')  # Extract and clean the width value
                try:
                    width_value = float(width_part)  # Convert to float if possible
                except ValueError:
                    width_value = 0.0  # Set default value in case of conversion error
                df.at[i, "width"] = width_value
            else:
                df.at[i, "width"] = None  # Set None if no width information found in the format

            # Update 'area' to keep only the first part (e.g., "42 m²")
            df.at[i, "area"] = " ".join(parts[0].split()[:1]).replace(',', '.').strip()
        else:
            df.at[i, "width"] = None  # Set width to None if area is None
    for i, phonenumber in enumerate(df['phonenumber']):        
        if isinstance(phonenumber, str):
            phonenumber = phonenumber.replace(' ', '').replace('.', '').strip()
            # Kiểm tra nếu số đầu tiên khác 0 thì thêm số 0 vào đầu
            if phonenumber[0] != '0':
                phonenumber = '0' + phonenumber
            df.at[i, 'phonenumber'] = phonenumber.strip()
            
    for i, title in enumerate(df['title']):
        if isinstance(title, str):
            title = re.sub(r'[^\w\s,.()\–]', '', title)
            title = title.lower()
            title = title.capitalize()
            df.at[i, 'title'] = title.strip()        
        

def extract_district_and_province(address):
    parts = address.split(',')
    if len(parts) >= 3:
        district = parts[-2].strip()
        province_city = parts[-1].strip()
        return district, province_city
    return None, None

data_normalization(buydata_df)

#buydata_df['area'] = buydata_df['area'].replace({',':'.'})

buydata_df['type_estate'] = buydata_df['type_estate'].replace({
    'Nhà mặt tiền': 'Nhà Mặt Phố',
    'Biệt thự, Villa': 'Nhà Biệt Thự, Liền Kề',
    'Nhà hẻm, ngõ': 'Nhà Trong Ngõ',
    'Chung cư': 'Căn Hộ Chung Cư',
    'Penthouse': 'Căn Hộ Chung Cư',
    'Tập thể, cư xá': 'Căn Hộ Chung Cư',
    'Căn hộ dịch vu, mini': 'Căn Hộ Chung Cư',
    'Đất thổ cư': 'Nhà Đất Thổ Cư',
    'Đất dự án, Khu dân cư': 'Đất Nền Dự Án',
    'Đất nông nghiệp, kho bãi': 'Đất Nông Nghiệp, Đất Vườn',
    'Chung cư': 'Căn Hộ Chung Cư',
    'Văn phòng': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Cửa hàng, shophouse': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Mặt bằng kinh doanh': 'Văn phòng, TTTM, Cửa hàng, Kiot',
    'Nhà xưởng, nhà kho': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
    'Bãi để xe': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
    'Đất trống': 'Nhà Xưởng, Mặt Bằng, Kho Bãi',
})

def write_data(df, field, data_list):
    if not isinstance(data_list, list):
        data_list = []  # Initialize as empty list if not already
    
    if field in df.columns:
        for value in df[field]:
            data_list.append(value)
    else:
        print(f"Error: '{field}' column not found in the DataFrame.")
    
# Populate lists with data from DataFrame
write_data(buydata_df, "title", title)
write_data(buydata_df, "price", price)
write_data(buydata_df, "area", area)
write_data(buydata_df, "type", type)
write_data(buydata_df, "type_estate", type_estate)
write_data(buydata_df, "image_links", image_links)
write_data(buydata_df, "bedroom", bedroom)
write_data(buydata_df, "description", description)
write_data(buydata_df, "width", width)
write_data(buydata_df, "direction", direction)
write_data(buydata_df, "toilet", toilet)
write_data(buydata_df, "address", address)
write_data(buydata_df, "law", law)
write_data(buydata_df, "floor", floor)
write_data(buydata_df, "geo_code", geo_code)
write_data(buydata_df, "district", district)
write_data(buydata_df, "province_city", province_city)
write_data(buydata_df, "phonenumber", phonenumber)

# Display the updated DataFrame
print("\nUpdated DataFrame:")
# Out:
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
# Latitude: 10.8354624, Longitude: 106.6646199
# Retry with modified address: Ngọc Khánh, Phường Kim Mã, Quận Ba Đình, Hà Nội
# Latitude: 21.0296462, Longitude: 105.8107234
# Latitude: 20.9706, Longitude: 105.61127
# Latitude: 10.8383323, Longitude: 106.6856316
# Latitude: 10.9003413, Longitude: 106.5978566
# Latitude: 10.7850816, Longitude: 106.6695679
# Latitude: 51.5, Longitude: 10.5
# Latitude: 10.82302, Longitude: 106.62965
# Retry with modified address: Tân Ấp, Phường Phúc Xá, Quận Ba Đình, Hà Nội
# Latitude: 21.0468824, Longitude: 105.8468091
# Latitude: 10.78379, Longitude: 106.63704
# Latitude: 10.7021141, Longitude: 106.7381428
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.7994545, Longitude: 106.6467812
# Latitude: 10.82302, Longitude: 106.62965
# Latitude: 10.8208076, Longitude: 106.6372509
# Latitude: 10.84863, Longitude: 106.77209
# Latitude: 20.92925, Longitude: 105.83584
# Latitude: 21.037, Longitude: 105.85663
# Latitude: 10.8342977, Longitude: 106.6817579
#
# Updated DataFrame:

# %%
buydata_df
# Out:
#                                                  title          price  area  \
# 0    Bán nhà Gò Vấp, Thống Nhất, P.11, sàn 121,4m2,...            5.7  61.3
# 1    Bán nhà mặt đường ngã ba Ngọc Khánh, Kim Mã, 3...           13.8  36.5
# 2    Bán đất Quốc Oai, Hà Nội, gần Nhà máy tin tiền...  123.456.789 đ   600
# 3    Nhà Dương Quãng Hàm P6 ( 1 trệt 1 lững 4 lầu )...           12.5    69
# 4    Xuất cảnh cần bán gấp Nhà Biệt Thự Tân Hiệp Hó...           18.5   430
# ..                                                 ...            ...   ...
# 166  CHỈ 1,9 TỶ CÓ DTS 40M2 - KHÔNG QH - SỔ HỒNG RI...            1.9    20
# 167  Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Câ...              6   109
# 168  Cần bán 100 m2 đất, mặt tiền 5m, tại Đông Mỹ, ...  123.456.789 đ   100
# 169  Bán nhà số 51B ngõ 383 phố Phúc Tân, phường Ph...            5.3    46
# 170  BÁN NHÀ GÓC 3 MẶT TIỀN, VỊ TRÍ SẦM UẤT BẬC I P...             30  67.5
#
#                                                address  \
# 0     Đường Thống Nhất, Phường 11, Quận Gò Vấp, TP.HCM
# 1    Đường Ngọc Khánh, Phường Kim Mã, Quận Ba Đình,...
# 2     Đường DH09, Xã Hòa Thạch, Huyện Quốc Oai, Hà Nội
# 3    Đường Dương Quảng Hàm, Phường 6, Quận Gò Vấp, ...
# 4    4/7H, Đường Tân Hiệp 19, Xã Tân Hiệp, Huyện Hó...
# ..                                                 ...
# 166  Đường Nguyễn Sỹ Sách, Phường 15, Quận Tân Bình...
# 167  1161, Đường Kha Vạn Cân, Phường Linh Trung, TP...
# 168  Đường Phân Lân - 105, Xã Đông Mỹ, Huyện Thanh ...
# 169  Số 51B ngõ 383, Đường Phúc Tân, Phường Phúc Tâ...
# 170  67/1, Đường Lê Đức Thọ, Phường 6, Quận Gò Vấp,...
#
#                                            description     type  \
# 0    BÁN NHÀ ĐƯỜNG THỐNG NHẤT P11 GÒ VẤP gần bệnh v...  Mua Bán
# 1    Bán nhà mặt đường ngã ba Ngọc Khánh, Kim Mã, n...  Mua Bán
# 2    Chính chủ bán đất xã Hòa Thạch + xã Phú Cát, Q...  Mua Bán
# 3    - Nhà P6 Dương Quãng hàm Hẻm Thông 1 xẹt xe hơ...  Mua Bán
# 4    Nhà hướng Nam 1 trệt 1 lầu xây dựng kiên cố, t...  Mua Bán
# ..                                                 ...      ...
# 166  BÁN NHÀ Nguyễn Sỹ Sách, phường 15, quận Tân Bì...  Mua Bán
# 167  Chính chủ bán gấp nhà mặt tiền số 1161 khu phố...  Mua Bán
# 168  Cần bán 100 m2 đất, mặt tiền 5m, tại Đông Mỹ, ...  Mua Bán
# 169  Bán nhà số 51B ngõ 383 phố Phúc Tân, phường Ph...  Mua Bán
# 170  Bán nhà góc 3 mặt tiền tại số 67/1 Lê Đức Thọ,...  Mua Bán
#
#                type_estate      law  floor bedroom toilet direction  \
# 0            Nhà Trong Ngõ  Sổ hồng    3.0       3      3      None
# 1              Nhà Mặt Phố    Sổ đỏ    NaN    None   None      None
# 2                     None    Sổ đỏ    NaN    None   None      None
# 3            Nhà Trong Ngõ  Sổ hồng    5.0       6      7      None
# 4    Nhà Biệt Thự, Liền Kề  Sổ hồng    2.0    None   None      None
# ..                     ...      ...    ...     ...    ...       ...
# 166          Nhà Trong Ngõ  Sổ hồng    NaN       2      2      None
# 167            Nhà Mặt Phố  Sổ hồng    NaN    None   None      None
# 168                   None    Sổ đỏ    NaN    None   None      None
# 169          Nhà Trong Ngõ    Sổ đỏ    4.0    None   None      None
# 170          Nhà Trong Ngõ  Sổ hồng    7.0      20     21      None
#
#                                            image_links  \
# 0    https://cloud.muaban.net/images/thumb-detail/2...
# 1    https://cloud.muaban.net/images/thumb-detail/2...
# 2    https://cloud.muaban.net/images/thumb-detail/2...
# 3    https://cloud.muaban.net/images/thumb-detail/2...
# 4    https://cloud.muaban.net/images/thumb-detail/2...
# ..                                                 ...
# 166  https://cloud.muaban.net/images/thumb-detail/2...
# 167  https://cloud.muaban.net/images/thumb-detail/2...
# 168  https://cloud.muaban.net/images/thumb-detail/2...
# 169  https://cloud.muaban.net/images/thumb-detail/2...
# 170  https://cloud.muaban.net/images/thumb-detail/2...
#
#                       geo_code width            district province_city
# 0    [10.8354624, 106.6646199]  None              Gò Vấp   Hồ Chí Minh
# 1    [21.0296462, 105.8107234]  None             Ba Đình        Hà Nội
# 2         [20.9706, 105.61127]  None            Quốc Oai        Hà Nội
# 3    [10.8383323, 106.6856316]   4.2              Gò Vấp   Hồ Chí Minh
# 4    [10.9003413, 106.5978566]  14.0             Hóc Môn   Hồ Chí Minh
# ..                         ...   ...                 ...           ...
# 166  [10.8208076, 106.6372509]  None            Tân Bình   Hồ Chí Minh
# 167      [10.84863, 106.77209]   4.1  Thủ Đức -  Thủ Đức   Hồ Chí Minh
# 168      [20.92925, 105.83584]  None           Thanh Trì        Hà Nội
# 169        [21.037, 105.85663]  None           Hoàn Kiếm        Hà Nội
# 170  [10.8342977, 106.6817579]   4.5              Gò Vấp   Hồ Chí Minh
#
# [171 rows x 17 columns]

# %%
buydata_df.to_csv('buy_data.csv', encoding='utf-8', index=False)

# %%
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

try:
    with connection.cursor() as cursor:
        # Xóa dữ liệu từ cả hai bảng pools_bds và pools_image
        cursor.execute("""
            DELETE pb, pi
            FROM pools_bds pb
            JOIN pools_image pi ON pb.BDS_id = pi.BDS_id
            WHERE pb.kind = 'Mua Bán' AND pi.content LIKE '%muaban.net%'
        """)
        connection.commit()

finally:
    connection.close()

# %%
import csv
import pymysql

# Thiết lập kết nối tới cơ sở dữ liệu MySQL với mã hóa utf8mb4
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='123456',
    database='estate',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

def is_decimal(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

try:
    with connection.cursor() as cursor:
        
        # Đọc dữ liệu từ file CSV và nhập vào MySQL
        with open('buy_data.csv', 'r', encoding='utf-8') as file:
            csv_data = csv.DictReader(file)
            for row in csv_data:
                try:
                    if not row['type_estate']:
                        continue
                    
                    district = row['district']
                    province_city = row['province_city']
                    
                    # Kiểm tra tồn tại address
                    cursor.execute("SELECT address_id FROM pools_address WHERE district = %s AND province_city = %s", (district, province_city))
                    existing_address = cursor.fetchone()
                    if existing_address:
                        address_id = existing_address['address_id']
                    else:
                        # Nếu không tìm thấy địa chỉ, bỏ qua dòng này
                        print(f"Không tìm thấy địa chỉ cho dòng: {row}")
                        continue
                    
                    # Kiểm tra pools_typeofbds 
                    bds_type = row['type_estate']
                    cursor.execute("SELECT Type_Id FROM pools_typeofbds WHERE TypeName = %s", (bds_type,))
                    existing_type = cursor.fetchone()
                    if existing_type:
                        type_id = existing_type['Type_Id']
                    else:
                        # Nếu không tìm thấy loại bất động sản, bỏ qua dòng này
                        print(f"Không tìm thấy loại bất động sản cho dòng: {row}")
                        continue
                    
                    # Thêm dữ liệu vào bảng pools_bds
                    title = row['title']
                    price = row['price']
                    area = row['area']
                    kind = row['type']
                    law = row['law']
                    bedroom = row['bedroom']
                    floor = row['floor']
                    description = row['description']
                    width = row['width']
                    direction = row['direction']
                    toilet = row['toilet']
                    location = row['address']
                    geocode = row['geo_code']
                    
                    # Handle 'price' column
                    if price.strip().lower() == 'thỏa thuận':
                        price = 0  # or set to a default value, like 0
                    elif not is_decimal(price):
                        price = 0  # or set to a default value

                    # Handle 'width' column
                    if not is_decimal(width):
                        width = 0  # or set to a default value

                    # Handle 'bedroom' column
                    if not bedroom.strip() or bedroom.lower() == 'null':
                        bedroom = 0  # or set to a default value
                       
                    # Handle 'floor' column 
                    if not floor.strip() or floor.lower() == 'null':
                        floor = 0  # or set to a default value

                    # Handle 'toilet' column (if needed)
                    if not is_decimal(toilet):
                        toilet = 0  # or set to a default value

                    # Kiểm tra geocode nếu là None hoặc rỗng, bỏ qua dòng này
                    if not geocode:
                        # print(f"Không có giá trị geocode cho dòng: {row}")
                        continue

                    # Chuyển geo_code thành string nếu nó là list
                    if isinstance(geocode, list):
                        geocode = str(geocode)

                    # Thêm dữ liệu vào bảng pools_bds
                    cursor.execute("""
                        INSERT INTO pools_bds (title, price, area, kind, law, bedroom, floor, address_id, Type_id, description, width, direction, toilet, location, geocode)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                    """, (title, price, area, kind, law, bedroom, floor, address_id, type_id, description, width, direction, toilet, location, geocode))
                    connection.commit()
                    
                    # Lấy BDS_id của BDS vừa thêm
                    cursor.execute("SELECT LAST_INSERT_ID()")
                    bds_id = cursor.fetchone()['LAST_INSERT_ID()']
                    
                    # Thêm dữ liệu vào bảng pools_image (nếu có)
                    if 'image_links' in row and row['image_links']:  # Kiểm tra xem cột 'image_link' có tồn tại và có giá trị không
                        image_link = row['image_links']
                        cursor.execute("INSERT INTO pools_image (BDS_id, content) VALUES (%s, %s)", (bds_id, image_link))
                        connection.commit()
                        
                except Exception as e:
                    print(f"Lỗi khi xử lý dòng: {row}")
                    print(e)
finally:
    connection.close()
# Out:
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
# Không tìm thấy địa chỉ cho dòng: {'title': 'Chính chủ bán gấp nhà mặt tiền 1161 Kha Vạn Cân, P.Linh Trung, Thủ Đức', 'price': '6', 'area': '109', 'address': '1161, Đường Kha Vạn Cân, Phường Linh Trung, TP. Thủ Đức - Quận Thủ Đức, TP.HCM', 'description': 'Chính chủ bán gấp nhà mặt tiền số 1161 khu phố 4 phường Linh Trung, Q.Thủ Đức cũ. Ngay cầu vượt Linh Xuân.\n- Kết cầu nhà cũ tiện xây dựng mới. Nhà 1 trệt có gác. Ngang 4,11m sâu 30m. Tổng diện tích đất công nhận : 109m2 thổ cư 100%. Diện tích thực 120m2. Diện tích xây dựng : 113m2.\n- Nhà 2 mặt tiền trước và sau thông thoáng, tiện ở và kinh doanh, ngăn phòng trọ có thu nhập ngay.\n- Mặt tiền Kha Vạn Cân kinh doanh đa ngành nghề.\n- Giá bán : 6 tỷ thương lượng chính chủ.\nHợp tác môi giới hoa hồng : 1.5% nhận đủ.\nLiên hệ : Anh Dưỡng cọc.', 'type': 'Mua Bán', 'type_estate': 'Nhà Mặt Phố', 'law': 'Sổ hồng', 'floor': '', 'bedroom': '', 'toilet': '', 'direction': '', 'image_links': 'https://cloud.muaban.net/images/thumb-detail/2024/05/31/181/8529112cc153482ca188b6629f1bb2c0.jpg', 'geo_code': '[10.84863, 106.77209]', 'width': '4.1', 'district': 'Thủ Đức -  Thủ Đức', 'province_city': 'Hồ Chí Minh'}
